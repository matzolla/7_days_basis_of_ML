# %% [markdown]
# #### Date: 28 Sept 2020
# #### content writter: Nken Allassan, CEO CO-founder of WedOO.ai
# ![stark.PNG](attachment:stark.PNG)

# %% [markdown]
# #### BASIC PYTHON TUTORIAL
#
# data scientist need to have this skills (you just need to understand the key concept of python)
# ### As a summary we will learn python to be data scientist!!!
#
# **content:**
#
# 1. [Introduction to python:](#1)
#    1. [Data types:](#2)
#    1. [Logic control flow:](#3)
#    1. [mathematical operations and strings](#16)
#    1. [Loop data structures:](#4)
#    1. [Dictionaries:](#5)
#    1. [List comprehension:](#6)
# 2. [Functions:](#8)
#    1. [User defined functions:](#9)
#    1. [Scope:](#10)
#    1. [Nested function:](#11)
#    1. [Default and flexible argument:](#12)
#    1. [Lambda functions:](#13)
#    1. [Anonymous functions:](#14)
#    1. [Iterators:](#15)

# %% [markdown]
# <a id='1'></a> <br>
# # 1. Introduction to python

# %% [markdown]
# <a id='2'></a> <br>
# ### Data types
# There are 5 basic data types: boolean,integer,float,object(categorical) and strings
# <br> we can convert one data type to another example from str to categorical from int to float
# <br> why is it so important?
# * make dataframe smaller in memory (we shall learn dataframe later)

# %%
# examples
float_value=15/7
b=int(float_value)
print(b) #display the values in the notebook
# Out:
# 2

# %% [markdown]
# We could apply same for float values that is int_value=5
# <br> a=float(int_value) it will give as answer **5.0** which is of type float
# <br> from this point of vue we could also determine if an integer or a float using the **is** method, is actually an integer or a float
# <br> it therefore returns a **boolean** (True/False) if the condition is respected
# <br> to get the type of a variable simply use the **type** method

# %%
#checking if a float is an integer
float_value is int #return False
#getting the type of the variable
type(float_value)
# Out:
# float

# %% [markdown]
# <a id='3'></a><br>
# ### Logic ,control flow
# <br>In this part we just compare variable of *same type* with each other
# <br>We will be using the comparison operator: <,>,==,<=,>=
# <br>boolean operators : **and**, **or**,**not**
# * comparison operators are mainly used in dataframes to compare variables of same structures
# * they could be useful to get insights or trend from data
#
# <br>We shall see other comparison method when dealing with dataframes and pandas

# %%
#comparison operators:
#they will return a boolean value either True or False
print(3<4)
print(4>6)
print(9==7)
# Out:
# True
# False
# False

# %%
#boolean operators
print((3<9) and (4>2))
print((8>5) or True) #we can compare two variables(which returns a boolean) directly with a boolean
# Out:
# True
# True

# %% [markdown]
# <a id='16'></a><br>
# ### Mathematical operations and strings
# * Mathematical operations
#
# <br>This part is easy to assimilate we simply make use of operations such as; **+, /, *, %,-,** on variables
# <br>mathematical operations are mostly encountered while programming in python or even while manipulating data
# <br>other operations can also be encountered such as incrementation a+=1 (same as a=a+1) with respect to any mathematical operator

# %%
##current operations
a=3+3 #addition
b=3/3 #division
c=5-2 #subtraction
d=8*2 #multiplication
e=5%2 # modulo(returns the remainder after the division operation)
a+=1# after this the final value for a will be 7 (since it was 6 firstly while treating a=3+3)
print("5%2 is : {}".format(e))
print(a)
# Out:
# 5%2 is : 1
# 7

# %% [markdown]
# * Strings
#
# <br>strings as defined above are a type of data structure which is not mutable(meaning they can't be modified)
# <br>they are however open to operations such as;
#
# * addition
# * multiplication
# * slicing
#
# <br>slicing is an operation in which we select arrays from a string from their giving indexes

# %%
#defining a string is simple
a="bonjour à vous"
print(a)
# Out:
# bonjour à vous

# %%
#addition of two strings
a="bonjour à vous"
b="WedOOers"
print(a+b)#printing it like that will concatenate the 2 strings we need to add a space ' '
print(a+' '+b)
#multiplication
a=a*2 #you could also write a*=2
print(a)
# Out:
# bonjour à vousbonjour à vous

# %%
#slicing from a string
#consider the array below
i="Yann Lecun"
slicing=i[0:9] #in python,the index alwqys start by 0
print("value of slicing: {}".format(slicing))
print('the length of the string is: {}'.format(len(slicing)))#determining the length of a string
# Out:
# value of slicing: Yann Lecu
# the length of the string is: 9

# %% [markdown]
# <a id='4'></a><br>
# ### Loop and data structures
# <br>We will learn basically **if** , **for** and **while** loops
# <br>they are mainly used to structure our program and to operate within variables via *conditions*
# * **while loop**

# %%
# Stay in loop if condition( i is not equal 5) is true
i = 0
while i != 5 :
    print('i is: ',i)
    i +=1 
print(i,' is equal to 5')
# Out:
# i is:  0
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# 5  is equal to 5

# %% [markdown]
# * **for loop**

# %%
# Stay in loop if condition( i is not equal 5) is true
lis = [1,2,3,4,5]#definition of a list we shall see very soon :)
for i in lis:
    print('i is: ',i)
print('')
# Out:
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# i is:  5

# %% [markdown]
# * **If condition**
#
# <br>execute the code **if** the condition is satisfied
# <br>we could also have the **if**, **else** condition
# <br>we could also have the **if**, **elif** ,**else** condition
#
# lets check the 3rd one

# %%
#execute the code if 
a=9
if a<2:
    print('{} is less than 2'.format(a))
elif a>2:
    print('{} is greater than 2'.format(a))
else:
    print('are you sure {} is a number?'.format(a))
# Out:
# 9 is greater than 2

# %% [markdown]
# <a id='5'></a><br>
# ### Dictionaries
# Why we need dictionary?
# * It has 'key' and 'value'
# * Faster than lists
# <br>
# What is key and value. Example:
# * dictionary = {'spain' : 'madrid'}
# * Key is spain.
# * Values is madrid.
# <br>
# <br>**It's that easy.**
# <br>Lets practice some other properties like keys(), values(), update, add, check, remove key, remove all entries and remove dicrionary.

# %%
#create dictionary and look its keys and values
dictionary = {'spain' : 'madrid','usa' : 'vegas'}
print(dictionary.keys())
print(dictionary.values())
# Out:
# dict_keys(['spain', 'usa'])
# dict_values(['madrid', 'vegas'])

# %%
# Keys have to be immutable objects like string, boolean, float, integer or tuples(tuples are immutable objects with 
#values seperated by brackets)
# List is not immutable
# Keys are unique
dictionary['spain'] = "barcelona"    # update existing entry
print(dictionary)
dictionary['france'] = "paris"       # Add new entry
print(dictionary)
del dictionary['spain']              # remove entry with key 'spain'
print(dictionary)
print('france' in dictionary)        # check include or not
dictionary.clear()                   # remove all entries in dict
print(dictionary)
# Out:
# {'spain': 'barcelona', 'usa': 'vegas'}
# {'spain': 'barcelona', 'usa': 'vegas', 'france': 'paris'}
# {'usa': 'vegas', 'france': 'paris'}
# True
# {}

# %%
# In order to run all code you need to take comment this line
# del dictionary         # delete entire dictionary     
print(dictionary)       # it gives error because dictionary is deleted

# %% [markdown]
# <a id='6'></a><br>
# ### List comprehension
# **One of the most important topic of this kernel**
# <br>We use list comprehension for data analysis often.
# <br> list comprehension: collapse for loops for building lists into a single line
# <br>Ex: num1 = [1,2,3] and we want to make it num2 = [2,3,4]. This can be done with for loop. However it is  unnecessarily long. We can make it one line code that is list comprehension.

# %%
# Example of list comprehension
num1 = [1,2,3]
num2 = [i + 1 for i in num1 ]
print(num2)
# Out:
# [2, 3, 4]

# %% [markdown]
# [i + 1 for i in num1 ]: list of comprehension
# <br> i +1: list comprehension syntax
# <br> for i in num1: for loop syntax
# <br> i: iterator
# <br> num1: iterable object

# %%
# Conditionals on iterable
num1 = [5,10,15]
num2 = [i**2 if i == 10 else i-5 if i < 7 else i+5 for i in num1]
print(num2)
# Out:
# [0, 100, 20]

# %% [markdown]
# ### NB
# * it is also important to note that list object also accept the **slicing** method
# * we can do mathematical operations (addition and multiplication) through list
# * list are mutable objects

# %% [markdown]
# <a id='8'></a><br>
# # 2. Functions

# %% [markdown]
# <a id='9'></a><br>
# ### user defined functions
# What we need to know about functions:
# * docstrings: documentation for functions. Example:
# <br>for f():
#     <br>"""This is docstring for documentation of function f"""
# * tuple: sequence of immutable python objects.
# <br>cant modify values
# <br>tuple uses paranthesis like tuple = (1,2,3)
# <br>unpack tuple into several variables like a,b,c = tuple

# %%
# example of what we learn above
def tuple_ex():
    """ return defined t tuple"""
    t = (1,2,3)
    return t
a,b,c = tuple_ex()
print(a,b,c)
# Out:
# 1 2 3

# %% [markdown]
# <a id='10'></a><br>
# ### Scope:
# What we need to know about scope:
# * global: defined main body in script
# * local: defined in a function
# * built in scope: names in predefined built in scope module such as print, len
# <br><br>Lets make some basic examples

# %%
# guess print what
x = 2
def f():
    x = 3
    return x
print(x)      # x = 2 global scope
print(f())    # x = 3 local scope
# Out:
# 2
# 3

# %%
# What if there is no local scope
x = 5
def f():
    y = 2*x        # there is no local scope x
    return y
print(f())         # it uses global scope x
# First local scopesearched, then global scope searched, if two of them cannot be found lastly built in scope searched.
# Out:
# 10

# %%
# How can we learn what is built in scope
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %% [markdown]
# <a id='11'></a><br>
# ### Nested function
# * function inside function.
# * There is a LEGB rule that is search local scope, enclosing function, global and built in scopes, respectively.

# %%
#nested function
def square():
    """ return square of value """
    def add():
        """ add two local variable """
        x = 2
        y = 3
        z = x + y
        return z
    return add()**2
print(square())
# Out:
# 25

# %% [markdown]
# <a id="12"></a> <br>
# ### DEFAULT and FLEXIBLE ARGUMENTS
# * Default argument example:
# <br> def f(a, b=1):
#         """ b = 1 is default argument"""
# * Flexible argument example:
# <br> def f(*args):
#        """ *args can be one or more"""
# <br>def f(** kwargs)
#        """ **kwargs is a dictionary"""
#
# <br><br> lets write some code to practice

# %%
# default arguments
def f(a, b = 1, c = 2):
    y = a + b + c
    return y
print(f(5))
# what if we want to change default arguments
print(f(5,4,3))
# Out:
# 8
# 12

# %%
# flexible arguments *args
def f(*args):
    for i in args:
        print(i)
f(1)
print("")
f(1,2,3,4)
# flexible arguments **kwargs that is dictionary
def f(**kwargs):
    """ print key and value of dictionary"""
    for key, value in kwargs.items():               # If you do not understand this part turn for loop part and look at dictionary in for loop
        print(key, " ", value)
f(country = 'spain', capital = 'madrid', population = 123456)
# Out:
# 1
#
# 1
# 2
# 3
# 4
# country   spain
# capital   madrid
# population   123456

# %% [markdown]
# <a id="13"></a> <br>
# ### Lambda Function
# Faster way of writing function

# %%
# lambda function
square = lambda x: x**2     # where x is name of argument
print(square(4))
tot = lambda x,y,z: x+y+z   # where x,y,z are names of arguments
print(tot(1,2,3))
# Out:
# 16
# 6

# %% [markdown]
# <a id="14"></a> <br>
# ### Anonymous Function
# Like lambda function but it can take more than one arguments.
# * map(func,seq) : applies a function to all the items in a list

# %%
number_list = [1,2,3]
y = map(lambda x:x**2,number_list)
print(list(y))
# Out:
# [1, 4, 9]

# %% [markdown]
# <a id="15"></a> <br>
# ### ITERATORS
# * iterable is an object that can return an iterator
# * iterable: an object with an associated iter() method
# <br> example: list, strings and dictionaries
# * iterator: produces next value with next() method

# %%
# iteration example
name = "ronaldo"
it = iter(name)
print(next(it))    # print next iteration
print(*it)         # print remaining iteration
# Out:
# r
# o n a l d o

# %% [markdown]
# zip(): zip lists

# %%
# zip example
list1 = [1,2,3,4]
list2 = [5,6,7,8]
z = zip(list1,list2)
print(z)
z_list = list(z)
print(z_list)
# Out:
# ...
# [(1, 5), (2, 6), (3, 7), (4, 8)]

# %%
un_zip = zip(*z_list)
un_list1,un_list2 = list(un_zip) # unzip returns tuble
print(un_list1)
print(un_list2)
print(type(un_list2))
# Out:
# (1, 2, 3, 4)
# (5, 6, 7, 8)
# <class 'tuple'>

# %% [markdown]
# # conclusion
# thanks for your stars and forks
# <br>**MACHINE LEARNING** https://www.kaggle.com/kanncaa1/machine-learning-tutorial-for-beginners/
# <br>we are open to suggestions ! cordially the **WedOO.ai team**
